# %%
! pip install -q gradio transformers torch black autopep8 reportlab requests

import dradio as gr
form transformears import pipeline
import torch
import ast
import re
from datetime import datetime
from pathlib import path
import json
import black
import autopep8
from reportlab.lib.pagesizes import letter,A4
from reportlab.platypus import simpleDoc template,paragraph,spacher,PageBreak,table,TableStyle
from reportlab.lib.styles import getSampleStyleSheet,paragraphStyle
from reportlab.lib.units import inch
from reportlab.lib import colors
import requests
